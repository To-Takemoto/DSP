# %%
date_dic = {"year":2023, "month":12, "day":24}
span = 16

# %%
import thinking_fun
graph_drawer = thinking_fun.TinkingGraph()
graph_drawer.draw_temperature_graph(date_dic, span)

# %%
dataset= graph_drawer.make_span_dataset(date_dic, span)
graph_drawer.draw_screen_time_graph(dataset)

# %%
graph_drawer.draw_scatter_plot(date_dic, span)
