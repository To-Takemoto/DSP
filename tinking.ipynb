# %%
year = 2023
month = 12
day = 24

# %%
date_dic = {"year":year, "month":month, "day":day}

# %%
import thinking_fun
graph_drawer = thinking_fun.TinkingGraph()
graph_drawer.draw_temperature_graph(date_dic, 5, 3)
# Out:
# 2023-12-24
# 2023-12-25
# 2023-12-26
# 2023-12-27
# 2023-12-28

# %%
dataset2 = thinking_fun.TinkingGraph().make_span_dataset(date_dic, 8)
thinking_fun.TinkingGraph().draw_screen_time_graph(dataset2)
