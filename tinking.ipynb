# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'IPAexGothic'
sns.set(font='IPAexGothic')

# %%
import utils, settings

# %%
dataset = pd.DataFrame([[100, 200, 50, 0], [300, 400, 600, 0], [50, 300, 60, 0], [100, 100, 100, 0]], 
                       columns=['A', 'B', 'C', 'D'], 
                       index=['4', '5', '6', '7'])

# %%
a = utils.DBHandler(settings.db_path).select_one_data("screen_time_table", f"date = {date}", )

# %%
#https://qiita.com/s_fukuzawa/items/6f9c1a3d4c4f98ae6eb1
#上より引用
fig, ax = plt.subplots(figsize=(10, 8))
for i in range(len(dataset)):
    ax.bar(dataset.columns, dataset.iloc[i], bottom=dataset.iloc[:i].sum())
    for j in range(len(dataset.columns)):
        plt.text(x=j, 
                 y=dataset.iloc[:i, j].sum() + (dataset.iloc[i, j] / 2), 
                 s=dataset.iloc[i, j], 
                 ha='center', 
                 va='bottom'
                )
ax.set(xlabel='支店名', ylabel='売り上げ')
ax.legend(dataset.index)
plt.show()
